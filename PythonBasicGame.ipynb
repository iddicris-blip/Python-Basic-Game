# %% [markdown]
# <a href="https://colab.research.google.com/github/iddicris-blip/Python-Basic-Game/blob/main/PythonBasicGame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

correct_number = int(random.randint(1, 10))


while True:
    input_number = int(input("Guess the correct number between 1 and 10: "))

    if input_number == correct_number:
        print("Congratulations! You guessed the number correctly!")
        break
    elif input_number < correct_number:
        print("Your guess is too low. Guess again.")
    else:
        print("Your guess is too high. Guess again.")
# Out:
# Guess the correct number between 1 and 10: 55
# Your guess is too high. Guess again.
# Guess the correct number between 1 and 10: 7
# Your guess is too high. Guess again.
# Guess the correct number between 1 and 10: 5
# Your guess is too high. Guess again.
# Guess the correct number between 1 and 10: 3
# Your guess is too low. Guess again.
# Guess the correct number between 1 and 10: 4
# Congratulations! You guessed the number correctly!
